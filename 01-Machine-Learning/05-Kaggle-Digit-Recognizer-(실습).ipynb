# %% [markdown]
# ## Kaggle (분류 예측 문제 도전)

# %% [markdown]
# - [손글씨 분류기 Digit Recognizer](https://www.kaggle.com/c/digit-recognizer)
# - Kaggle 계정이 없으신 분은 캐글에 회원가입 합니다.

# %%
# 튜토리얼 진행을 위한 모듈 import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os

# 경고 메시지 출력 표기 생략
warnings.filterwarnings('ignore')

# SEED 설정
SEED = 30

DATA = 'digit-recognizer'

# %%
train = pd.read_csv(os.path.join(DATA, 'train.csv'))
test = pd.read_csv(os.path.join(DATA, 'test.csv'))
submission = pd.read_csv(os.path.join(DATA, 'sample_submission.csv'))

# %% [markdown]
# - train: 학습용 데이터셋
# - test: 예측용 데이터셋

# %%
print(train.shape)
train.head()

# %%
w, h = 2, 5
fig, axes = plt.subplots(w, h)
fig.set_size_inches(12, 6)
for i in range(w*h):
    axes[i//h, i%h].imshow(train.iloc[i, 1:].values.reshape(-1, 28), cmap='gray')
    axes[i//h, i%h].set_title(train.iloc[i, 0], fontsize=20)
    axes[i//h, i%h].axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 학습용 데이터셋(train) 분할

# %%
from sklearn.model_selection import train_test_split

SEED = 123

# %%
# 코드를 입력해 주세요
x_train, x_test, y_train, y_test =

# %%
# 코드를 입력해 주세요
x_train.shape, x_test.shape

# %% [markdown]
# ## 모델 정의

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# 코드를 입력해 주세요
knn =

# %% [markdown]
# ### 학습(fit)

# %%
# 코드를 입력해 주세요
knn.

# %% [markdown]
# ### 예측(predict)

# %%
# 코드를 입력해 주세요
prediction =

# %% [markdown]
# ### 검증셋에 대한 정확도 산출(Accuracy)

# %%
# 코드를 입력해 주세요
acc = 
print(f'accuracy: {acc * 100: .2f} %')

# %% [markdown]
# ### 최적의 n_neighbors 찾기
#
# - `k=1` ~ `k=10`까지의 정확도를 출력

# %%
# 코드를 입력해 주세요

# %% [markdown]
# ## 테스트셋(test)으로 예측

# %%
# 코드를 입력해 주세요
prediction =

# %% [markdown]
# ## 결과 저장(submission)

# %%
submission['Label'] = prediction
display(submission)
submission.to_csv('output.csv', index=False)
